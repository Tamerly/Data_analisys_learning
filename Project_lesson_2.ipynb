# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamerly/Data_analisys_learning/blob/main/Project_lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# to work with data the following cell below should be run

# %%
# !gdown --id 146b22Rct6n6Ywh6wZvFGs7dhmOavwtF4
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=146b22Rct6n6Ywh6wZvFGs7dhmOavwtF4
# To: /content/bookings.csv
# 100% 12.2M/12.2M [00:00<00:00, 34.0MB/s]

# %%
import pandas as pd

# %% [markdown]
# In this project I have to resolve 9 tasks to check how I work with data

# %% [markdown]
# Импортируйте библиотеку pandas как pd. Загрузите датасет bookings.csv. Проверьте размер таблицы, типы переменных, а затем выведите первые 7 строк, чтобы посмотреть на данные.

# %%
df = pd.read_csv('/content/bookings.csv', sep=';')

# %%
df.shape
# Out:
# (119390, 21)

# %%
df.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
df.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
# 5               July                        27                          1
# 6               July                        27                          1
#
#    Stays in Weekend nights  Stays in week nights  ...  Adults  Children  \
# 0                        0                     0  ...       2       0.0
# 1                        0                     0  ...       2       0.0
# 2                        0                     1  ...       1       0.0
# 3                        0                     1  ...       1       0.0
# 4                        0                     2  ...       2       0.0
# 5                        0                     2  ...       2       0.0
# 6                        0                     2  ...       2       0.0
#
#    Babies  Meal Country Reserved Room Type Assigned room type customer type  \
# 0       0    BB     PRT                  C                  C     Transient
# 1       0    BB     PRT                  C                  C     Transient
# 2       0    BB     GBR                  A                  C     Transient
# 3       0    BB     GBR                  A                  A     Transient
# 4       0    BB     GBR                  A                  A     Transient
# 5       0    BB     GBR                  A                  A     Transient
# 6       0    BB     PRT                  C                  C     Transient
#
#   Reservation Status Reservation status_date
# 0          Check-Out              2015-07-01
# 1          Check-Out              2015-07-01
# 2          Check-Out              2015-07-02
# 3          Check-Out              2015-07-02
# 4          Check-Out              2015-07-03
# 5          Check-Out              2015-07-03
# 6          Check-Out              2015-07-03
#
# [7 rows x 21 columns]

# %% [markdown]
# Приведите названия колонок к нижнему регистру и замените пробелы на знак нижнего подчеркивания.

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
def rename_columns(df):
    lst = []
    for i_column in df.columns:
        j = list(i_column.lower())
        for ltr in j:
            if ltr == ' ':
                j[j.index(ltr)] = '_'
    return lst

# %%
lst_test = rename_columns(df)
# Out:
# hotel
# is_canceled
# lead_time
# arrival_full_date
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# stays_total_nights
# adults
# children
# babies
# meal
# country
# reserved_room_type
# assigned_room_type
# customer_type
# reservation_status
# reservation_status_date

# %%
def rename_columns(df):
  df.columns = df.columns.str.lower().str.replace(' ', '_')
  return df

# %%
df = rename_columns(df)
df
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# 1                    2015               July                        27
# 2                    2015               July                        27
# 3                    2015               July                        27
# 4                    2015               July                        27
# ...                   ...                ...                       ...
# 119385               2017             August                        35
# 119386               2017             August                        35
# 119387               2017             August                        35
# 119388               2017             August                        35
# 119389               2017             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 0                               1                        0
# 1                               1                        0
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  ...  adults  children  babies  meal country  \
# 0                          0  ...       2       0.0       0    BB     PRT
# 1                          0  ...       2       0.0       0    BB     PRT
# 2                          1  ...       1       0.0       0    BB     GBR
# 3                          1  ...       1       0.0       0    BB     GBR
# 4                          2  ...       2       0.0       0    BB     GBR
# ...                      ...  ...     ...       ...     ...   ...     ...
# 119385                     5  ...       2       0.0       0    BB     BEL
# 119386                     5  ...       3       0.0       0    BB     FRA
# 119387                     5  ...       2       0.0       0    BB     DEU
# 119388                     5  ...       2       0.0       0    BB     GBR
# 119389                     7  ...       2       0.0       0    HB     DEU
#
#        reserved_room_type assigned_room_type customer_type reservation_status  \
# 0                       C                  C     Transient          Check-Out
# 1                       C                  C     Transient          Check-Out
# 2                       A                  C     Transient          Check-Out
# 3                       A                  A     Transient          Check-Out
# 4                       A                  A     Transient          Check-Out
# ...                   ...                ...           ...                ...
# 119385                  A                  A     Transient          Check-Out
# 119386                  E                  E     Transient          Check-Out
# 119387                  D                  D     Transient          Check-Out
# 119388                  A                  A     Transient          Check-Out
# 119389                  A                  A     Transient          Check-Out
#
#        reservation_status_date
# 0                   2015-07-01
# 1                   2015-07-01
# 2                   2015-07-02
# 3                   2015-07-02
# 4                   2015-07-03
# ...                        ...
# 119385              2017-09-06
# 119386              2017-09-07
# 119387              2017-09-07
# 119388              2017-09-07
# 119389              2017-09-07
#
# [119390 rows x 21 columns]

# %% [markdown]
# Пользователи из каких стран совершили наибольшее число успешных бронирований? Укажите топ-5.

# %%
filter_cancelled = df['is_canceled'] == 0

# %%
df[filter_cancelled].groupby('country')['is_canceled'].count().reset_index().sort_values('is_canceled', ascending=False).head(5)
# Out:
#     country  is_canceled
# 125     PRT        21071
# 57      GBR         9676
# 54      FRA         8481
# 50      ESP         6391
# 42      DEU         6069

# %% [markdown]
# На сколько ночей в среднем бронируют отели разных типов

# %%
df.groupby('hotel').agg({'stays_total_nights' : 'mean'})
# Out:
#               stays_total_nights
# hotel
# City Hotel              2.978142
# Resort Hotel            4.318547

# %% [markdown]
# Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга. Сколько подобных наблюдений встретилось в датасете

# %%
df.head(1)
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  ...  adults  children  \
# 0                        0                     0  ...       2       0.0
#
#    babies  meal country reserved_room_type assigned_room_type customer_type  \
# 0       0    BB     PRT                  C                  C     Transient
#
#   reservation_status reservation_status_date
# 0          Check-Out              2015-07-01
#
# [1 rows x 21 columns]

# %%
count_different = (
    df['assigned_room_type'] != df['reserved_room_type']
).sum()
count_different
# Out:
# 14917

# %% [markdown]
# Проанализируйте даты запланированного прибытия.
#
# *   На какой месяц чаще всего успешно оформляли бронь в 2016? Изменился ли самый популярный месяц в 2017?
# *   Сгруппируйте данные по годам и проверьте, на какой месяц бронирования отеля типа City Hotel отменялись чаще всего в каждый из периодов.

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df['is_canceled'].value_counts()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
df.loc[df['is_canceled'] == 0]

# %%
df_2016 = df.loc[df['is_canceled'] == 0][df['reservation_status_date'].dt.year == 2016]
df_2016
# Out:
# <ipython-input-107-6a38e3a20e13>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2016 = df.loc[df['is_canceled'] == 0][df['reservation_status_date'].dt.year == 2016]
#                hotel is_canceled  lead_time arrival_full_date  \
# 3446    Resort Hotel           0        183        2015-12-08
# 3469    Resort Hotel           0         49        2015-12-17
# 3564    Resort Hotel           0         65        2015-12-23
# 3582    Resort Hotel           0         57        2015-12-24
# 3614    Resort Hotel           0        112        2015-12-26
# ...              ...         ...        ...               ...
# 103757    City Hotel           0         74        2016-12-29
# 103759    City Hotel           0         19        2016-12-29
# 103760    City Hotel           0         23        2016-12-30
# 103761    City Hotel           0         16        2016-12-29
# 103762    City Hotel           0         16        2016-12-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 3446                 2015           December                        50
# 3469                 2015           December                        51
# 3564                 2015           December                        52
# 3582                 2015           December                        52
# 3614                 2015           December                        52
# ...                   ...                ...                       ...
# 103757               2016           December                        53
# 103759               2016           December                        53
# 103760               2016           December                        53
# 103761               2016           December                        53
# 103762               2016           December                        53
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 3446                            8                        8
# 3469                           17                        6
# 3564                           23                        2
# 3582                           24                        2
# 3614                           26                        2
# ...                           ...                      ...
# 103757                         29                        0
# 103759                         29                        0
# 103760                         30                        0
# 103761                         29                        0
# 103762                         29                        0
#
#         stays_in_week_nights  ...  adults  children  babies  meal country  \
# 3446                      20  ...       2       0.0       0    BB     GBR
# 3469                      13  ...       2       0.0       0    BB     DEU
# 3564                       8  ...       2       0.0       0    BB     IRL
# 3582                       6  ...       2       0.0       0    BB     CHE
# 3614                       4  ...       2       2.0       0    BB     ESP
# ...                      ...  ...     ...       ...     ...   ...     ...
# 103757                     2  ...       2       1.0       0    BB     PRT
# 103759                     2  ...       2       0.0       1    BB     PRT
# 103760                     1  ...       3       0.0       0    BB     USA
# 103761                     2  ...       2       0.0       0    BB     BRA
# 103762                     2  ...       2       0.0       0    BB     BRA
#
#        reserved_room_type assigned_room_type customer_type reservation_status  \
# 3446                    E                  E     Transient          Check-Out
# 3469                    E                  E     Transient          Check-Out
# 3564                    E                  E     Transient          Check-Out
# 3582                    D                  D     Transient          Check-Out
# 3614                    G                  G     Transient          Check-Out
# ...                   ...                ...           ...                ...
# 103757                  D                  K     Transient          Check-Out
# 103759                  F                  F     Transient          Check-Out
# 103760                  D                  D     Transient          Check-Out
# 103761                  D                  D     Transient          Check-Out
# 103762                  D                  D     Transient          Check-Out
#
#        reservation_status_date
# 3446                2016-01-05
# 3469                2016-01-05
# 3564                2016-01-02
# 3582                2016-01-01
# 3614                2016-01-01
# ...                        ...
# 103757              2016-12-31
# 103759              2016-12-31
# 103760              2016-12-31
# 103761              2016-12-31
# 103762              2016-12-31
#
# [36369 rows x 21 columns]

# %%
df_2016.groupby(df_2016['reservation_status_date'].dt.month).agg({'is_canceled': 'count'}).sort_values('is_canceled', ascending=False)
# Out:
#                          is_canceled
# reservation_status_date
# 10                              3694
# 5                               3593
# 9                               3348
# 4                               3347
# 8                               3240
# 3                               3194
# 6                               3168
# 7                               3080
# 11                              3052
# 2                               2435
# 12                              2233
# 1                               1985

# %% [markdown]
# Ответ - Октябрь это месяц с самым частым успешным бронированием в 2016 году

# %%
df.head(1)
# Out:
#           hotel is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel           0        342        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  ...  adults  children  \
# 0                        0                     0  ...       2       0.0
#
#    babies  meal country reserved_room_type assigned_room_type customer_type  \
# 0       0    BB     PRT                  C                  C     Transient
#
#   reservation_status reservation_status_date
# 0          Check-Out              2015-07-01
#
# [1 rows x 21 columns]

# %%
df_2017 = df.loc[df['is_canceled'] == 0][df['reservation_status_date'].dt.year == 2017]
df_2017
# Out:
# <ipython-input-117-239c88f9b10d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2017 = df.loc[df['is_canceled'] == 0][df['reservation_status_date'].dt.year == 2017]
#                hotel is_canceled  lead_time arrival_full_date  \
# 9924    Resort Hotel           0          0        2017-01-25
# 10233   Resort Hotel           0         70        2017-02-22
# 10387   Resort Hotel           0          7        2017-03-02
# 11115   Resort Hotel           0          8        2017-04-21
# 11125   Resort Hotel           0        108        2017-04-21
# ...              ...         ...        ...               ...
# 119385    City Hotel           0         23        2017-08-30
# 119386    City Hotel           0        102        2017-08-31
# 119387    City Hotel           0         34        2017-08-31
# 119388    City Hotel           0        109        2017-08-31
# 119389    City Hotel           0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 9924                 2017            January                         4
# 10233                2017           February                         8
# 10387                2017              March                         9
# 11115                2017              April                        16
# 11125                2017              April                        16
# ...                   ...                ...                       ...
# 119385               2017             August                        35
# 119386               2017             August                        35
# 119387               2017             August                        35
# 119388               2017             August                        35
# 119389               2017             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 9924                           25                        0
# 10233                          22                        0
# 10387                           2                        0
# 11115                          21                        0
# 11125                          21                        4
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_week_nights  ...  adults  children  babies  meal country  \
# 9924                       1  ...       1       0.0       0    BB     PRT
# 10233                      4  ...       2       0.0       0    BB     GBR
# 10387                      3  ...       1       0.0       0    BB     BEL
# 11115                      1  ...       2       0.0       0    BB     PRT
# 11125                      7  ...       2       0.0       0    BB     PRT
# ...                      ...  ...     ...       ...     ...   ...     ...
# 119385                     5  ...       2       0.0       0    BB     BEL
# 119386                     5  ...       3       0.0       0    BB     FRA
# 119387                     5  ...       2       0.0       0    BB     DEU
# 119388                     5  ...       2       0.0       0    BB     GBR
# 119389                     7  ...       2       0.0       0    HB     DEU
#
#        reserved_room_type assigned_room_type    customer_type  \
# 9924                    A                  A        Transient
# 10233                   A                  C  Transient-Party
# 10387                   A                  C  Transient-Party
# 11115                   A                  D        Transient
# 11125                   E                  E        Transient
# ...                   ...                ...              ...
# 119385                  A                  A        Transient
# 119386                  E                  E        Transient
# 119387                  D                  D        Transient
# 119388                  A                  A        Transient
# 119389                  A                  A        Transient
#
#        reservation_status reservation_status_date
# 9924            Check-Out              2017-01-26
# 10233           Check-Out              2017-02-26
# 10387           Check-Out              2017-03-05
# 11115           Check-Out              2017-04-22
# 11125           Check-Out              2017-05-02
# ...                   ...                     ...
# 119385          Check-Out              2017-09-06
# 119386          Check-Out              2017-09-07
# 119387          Check-Out              2017-09-07
# 119388          Check-Out              2017-09-07
# 119389          Check-Out              2017-09-07
#
# [25335 rows x 21 columns]

# %%
df.groupby(df['reservation_status_date'].dt.month).agg({'is_canceled': 'count'}).sort_values('is_canceled', ascending=False)
# Out:
#                          is_canceled
# reservation_status_date
# 7                              12106
# 8                              11249
# 10                             11143
# 1                              10681
# 5                              10304
# 3                              10230
# 4                               9999
# 2                               9498
# 9                               9403
# 6                               9278
# 11                              8099
# 12                              7400

# %% [markdown]
# В 2017 году самым популярным месяцем оказался Июль
